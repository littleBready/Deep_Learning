# %% [markdown]
# # ECBM E6040 Homework 2 - Programming Problem

# %%
import theano
import theano.tensor as T
from hw2b import load_data, LogisticRegression, HiddenLayer, myMLP, test_mlp
# Out:
# Using gpu device 0: GRID K520 (CNMeM is disabled, cuDNN Version is too old. Update to v5, was 3007.)

# %% [markdown]
# ### Problem b: Bullet 2: Comparison between _tanh_ and _softmax_

# %% [markdown]
# ### Using softmax
# #### Parameters:
# learning_rate=0.01
# L1_reg=0.00
# L2_reg=0.0001
# n_epochs = 250
# batch_size=20
# n_layer = [250, 250]
# activation = T.nnet.softmax

# %%
test_mlp(n_epochs = 250, activation = T.nnet.softmax, n_layer = [250, 250], verbose = True)
# Out:
# ... loading data
# ... building the model
# ... training
# epoch 1, minibatch 3296/3296, validation error 81.161202 %
#      epoch 1, minibatch 3296/3296, test error of best model 80.415065 %
# epoch 2, minibatch 3296/3296, validation error 81.161202 %
# epoch 3, minibatch 3296/3296, validation error 81.161202 %
# Optimization complete. Best validation score of 81.161202 % obtained at iteration 3296, with test performance 80.415065 %
# The code for file hw2b.py ran for 0.73m
# 0.19584934665641829

# %% [markdown]
# ### Using tanh
# #### Parameters:
# learning_rate=0.01
# L1_reg=0.00
# L2_reg=0.0001
# n_epochs = 250
# batch_size=20
# n_layer = [250, 250]
# activation = T.tanh

# %%
test_mlp(n_epochs = 250, activation = T.tanh, n_layer = [250, 250], verbose = True)
# Out:
# ... loading data
# ... building the model
# ... training
# epoch 1, minibatch 3296/3296, validation error 81.038251 %
#      epoch 1, minibatch 3296/3296, test error of best model 80.330515 %
# epoch 2, minibatch 3296/3296, validation error 63.620219 %
#      epoch 2, minibatch 3296/3296, test error of best model 64.177556 %
# epoch 3, minibatch 3296/3296, validation error 49.549180 %
#      epoch 3, minibatch 3296/3296, test error of best model 52.659493 %
# epoch 4, minibatch 3296/3296, validation error 42.185792 %
#      epoch 4, minibatch 3296/3296, test error of best model 45.134512 %
# epoch 5, minibatch 3296/3296, validation error 38.169399 %
#      epoch 5, minibatch 3296/3296, test error of best model 41.010761 %
# epoch 6, minibatch 3296/3296, validation error 35.969945 %
#      epoch 6, minibatch 3296/3296, test error of best model 38.312836 %
# epoch 7, minibatch 3296/3296, validation error 34.057377 %
# ...

# %% [markdown]
# #### Observation
# The test accuracy of using softmax is much worse than using tanh, from which we can conclude that the choice of activation function will largely influence the result.

# %% [markdown]
# ### Problem b: Bullet 3: Experiment with the number of hidden layers

# %%
n_layer = [250]
test_mlp(activation = T.tanh, n_layer = n_layer, n_epochs = 150, verbose = True)
# Out:
# ... loading data
# ... building the model
# ... training
# epoch 1, minibatch 3296/3296, validation error 80.778689 %
#      epoch 1, minibatch 3296/3296, test error of best model 80.153728 %
# epoch 2, minibatch 3296/3296, validation error 71.816940 %
#      epoch 2, minibatch 3296/3296, test error of best model 71.906226 %
# epoch 3, minibatch 3296/3296, validation error 59.207650 %
#      epoch 3, minibatch 3296/3296, test error of best model 60.395849 %
# epoch 4, minibatch 3296/3296, validation error 49.918033 %
#      epoch 4, minibatch 3296/3296, test error of best model 51.936972 %
# epoch 5, minibatch 3296/3296, validation error 42.950820 %
#      epoch 5, minibatch 3296/3296, test error of best model 45.611068 %
# epoch 6, minibatch 3296/3296, validation error 38.661202 %
#      epoch 6, minibatch 3296/3296, test error of best model 41.448885 %
# epoch 7, minibatch 3296/3296, validation error 36.024590 %
# ...

# %%
n_layer = [250, 250, 250]
test_mlp(activation = T.tanh, n_layer = n_layer, n_epochs = 150, verbose = True)
# Out:
# ... loading data
# ... building the model
# ... training
# epoch 1, minibatch 3296/3296, validation error 80.409836 %
#      epoch 1, minibatch 3296/3296, test error of best model 79.446580 %
# epoch 2, minibatch 3296/3296, validation error 58.770492 %
#      epoch 2, minibatch 3296/3296, test error of best model 60.707148 %
# epoch 3, minibatch 3296/3296, validation error 44.275956 %
#      epoch 3, minibatch 3296/3296, test error of best model 47.313605 %
# epoch 4, minibatch 3296/3296, validation error 39.385246 %
#      epoch 4, minibatch 3296/3296, test error of best model 42.671022 %
# epoch 5, minibatch 3296/3296, validation error 34.959016 %
#      epoch 5, minibatch 3296/3296, test error of best model 37.843966 %
# epoch 6, minibatch 3296/3296, validation error 31.748634 %
#      epoch 6, minibatch 3296/3296, test error of best model 34.254420 %
# epoch 7, minibatch 3296/3296, validation error 29.699454 %
# ...

# %%
n_layer = [250, 250, 250, 250, 250]
test_mlp(activation = T.tanh, n_layer = n_layer, n_epochs = 150, verbose = True)
# Out:
# ... loading data
# ... building the model
# ... training
# epoch 1, minibatch 3296/3296, validation error 75.000000 %
#      epoch 1, minibatch 3296/3296, test error of best model 73.209070 %
# epoch 2, minibatch 3296/3296, validation error 52.172131 %
#      epoch 2, minibatch 3296/3296, test error of best model 53.631822 %
# epoch 3, minibatch 3296/3296, validation error 44.617486 %
#      epoch 3, minibatch 3296/3296, test error of best model 46.798616 %
# epoch 4, minibatch 3296/3296, validation error 39.767760 %
#      epoch 4, minibatch 3296/3296, test error of best model 42.071483 %
# epoch 5, minibatch 3296/3296, validation error 35.696721 %
#      epoch 5, minibatch 3296/3296, test error of best model 38.182168 %
# epoch 6, minibatch 3296/3296, validation error 32.704918 %
#      epoch 6, minibatch 3296/3296, test error of best model 34.235204 %
# epoch 7, minibatch 3296/3296, validation error 30.177596 %
# ...

# %%
n_layer = [250, 250, 250, 250, 250, 250, 250]
test_mlp(activation = T.tanh, n_layer = n_layer, n_epochs = 150, verbose = True)
# Out:
# ... loading data
# ... building the model
# ... training
# epoch 1, minibatch 3296/3296, validation error 72.431694 %
#      epoch 1, minibatch 3296/3296, test error of best model 72.455803 %
# epoch 2, minibatch 3296/3296, validation error 55.423497 %
#      epoch 2, minibatch 3296/3296, test error of best model 55.799385 %
# epoch 3, minibatch 3296/3296, validation error 45.969945 %
#      epoch 3, minibatch 3296/3296, test error of best model 47.463490 %
# epoch 4, minibatch 3296/3296, validation error 36.653005 %
#      epoch 4, minibatch 3296/3296, test error of best model 38.946964 %
# epoch 5, minibatch 3296/3296, validation error 33.688525 %
#      epoch 5, minibatch 3296/3296, test error of best model 35.499616 %
# epoch 6, minibatch 3296/3296, validation error 31.147541 %
#      epoch 6, minibatch 3296/3296, test error of best model 32.106072 %
# epoch 7, minibatch 3296/3296, validation error 29.221311 %
# ...

# %%
acc1 = [0.78470407378939278,
       0.79865488086087622,
       0.79780937740199842,
       0.79427363566487319]

# %% [markdown]
# Plot the result (reproducing Figure 1)

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
x = 1,3,5,7
fig, ax = plt.subplots()
ax.grid(True)
plt.plot(x, np.array(acc1)*100.0)
plt.ylabel('Test Accuracy, [%]')
plt.xlabel('Number of Layers')
plt.title('MLP on SVHN Dataset')
plt.xlim(0, 8)
plt.ylim(70, 83)
plt.show()

# %% [markdown]
# Document the choice of parameters, and discuss what you discover.
# #### Parameters:
# learning_rate = 0.01
# L1_reg = 0.00
# L2_reg = 0.0001
# n_epochs = 150
# batch_size = 20
# n_neurons_in_each_layer = 250
# activation = T.tanh
# patience = 9000
# improvement_threshold = 0.995

# %% [markdown]
# #### Observation
# In general, we can see the tendency from the plot that the test accuracy increases with the number of hidden layer if each layer contains the same amount of neurons. It is because when the number of hidden layer increases, the training times will increase, the parameter W will become better. In my result, the accuracy when number of hidden layer equals to 7 is slightly lower than 5 is because the choice of epoch is 150, patience = 9000, improvement_threshold = 0.995. These early stop parameters cause the training of #hidden_layers=5 early stopped. If choosing a bigger patience and epoch, the training will get a more precise result, in which the test accuracy will increase with the number of hidden layer.

# %% [markdown]
# #### Result of another set of hyperparameters
# n_epochs = 200
# patience = 8000
# improvement_threshold = 0.99
# acc = [0.7254035357417371,
#        0.78320522674865489,
#        0.81702536510376633,
#        0.76798616448885471]
# #### Reason of not choosing
# As for this set of hyperparameters, when I first experiment with hidden_layers = 3, the test_score = 21.679477%, which means the test_accuracy = 0.783205 exceeding 78%. However, when I complete all #hidden_layers, I found the accuracy is only 0.7254035357417371, which means it stops too earlier because of the decreasing of patience, so I set patience to 90000 and produce the results.

# %% [markdown]
# ### Problem b: Bullet 4: Experiment with the number of hidden layers, but fix the total number of neurons

# %%
total_number = 840
n_layer = [840]
test_mlp(activation=T.tanh, n_layer=n_layer, n_epochs=150, verbose = True)
# Out:
# ... loading data
# ... building the model
# ... training
# epoch 1, minibatch 3296/3296, validation error 79.494536 %
#      epoch 1, minibatch 3296/3296, test error of best model 78.900846 %
# epoch 2, minibatch 3296/3296, validation error 71.256831 %
#      epoch 2, minibatch 3296/3296, test error of best model 71.591084 %
# epoch 3, minibatch 3296/3296, validation error 59.275956 %
#      epoch 3, minibatch 3296/3296, test error of best model 60.438125 %
# epoch 4, minibatch 3296/3296, validation error 50.628415 %
#      epoch 4, minibatch 3296/3296, test error of best model 52.697925 %
# epoch 5, minibatch 3296/3296, validation error 43.674863 %
#      epoch 5, minibatch 3296/3296, test error of best model 46.606457 %
# epoch 6, minibatch 3296/3296, validation error 39.918033 %
#      epoch 6, minibatch 3296/3296, test error of best model 42.578786 %
# epoch 7, minibatch 3296/3296, validation error 37.322404 %
# ...

# %%
total_number = 840
n_layer = [420, 420]
test_mlp(activation=T.tanh, n_layer=n_layer, n_epochs=150, verbose = True)
# Out:
# ... loading data
# ... building the model
# ... training
# epoch 1, minibatch 3296/3296, validation error 80.928962 %
#      epoch 1, minibatch 3296/3296, test error of best model 80.215219 %
# epoch 2, minibatch 3296/3296, validation error 62.732240 %
#      epoch 2, minibatch 3296/3296, test error of best model 62.444274 %
# epoch 3, minibatch 3296/3296, validation error 49.043716 %
#      epoch 3, minibatch 3296/3296, test error of best model 52.336664 %
# epoch 4, minibatch 3296/3296, validation error 41.270492 %
#      epoch 4, minibatch 3296/3296, test error of best model 44.312068 %
# epoch 5, minibatch 3296/3296, validation error 38.907104 %
#      epoch 5, minibatch 3296/3296, test error of best model 41.114527 %
# epoch 6, minibatch 3296/3296, validation error 37.062842 %
#      epoch 6, minibatch 3296/3296, test error of best model 39.273636 %
# epoch 7, minibatch 3296/3296, validation error 35.273224 %
# ...

# %%
total_number = 840
n_layer = [280, 280, 280]
test_mlp(activation=T.tanh, n_layer=n_layer, n_epochs=150, verbose = True)
# Out:
# ... loading data
# ... building the model
# ... training
# epoch 1, minibatch 3296/3296, validation error 80.765027 %
#      epoch 1, minibatch 3296/3296, test error of best model 79.973098 %
# epoch 2, minibatch 3296/3296, validation error 57.377049 %
#      epoch 2, minibatch 3296/3296, test error of best model 59.961568 %
# epoch 3, minibatch 3296/3296, validation error 44.453552 %
#      epoch 3, minibatch 3296/3296, test error of best model 47.182936 %
# epoch 4, minibatch 3296/3296, validation error 38.032787 %
#      epoch 4, minibatch 3296/3296, test error of best model 41.837048 %
# epoch 5, minibatch 3296/3296, validation error 34.890710 %
#      epoch 5, minibatch 3296/3296, test error of best model 37.709454 %
# epoch 6, minibatch 3296/3296, validation error 33.319672 %
#      epoch 6, minibatch 3296/3296, test error of best model 35.207533 %
# epoch 7, minibatch 3296/3296, validation error 31.489071 %
# ...

# %%
total_number = 840
n_layer = [210, 210, 210, 210]
test_mlp(activation=T.tanh, n_layer=n_layer, n_epochs=150, verbose = True)
# Out:
# ... loading data
# ... building the model
# ... training
# epoch 1, minibatch 3296/3296, validation error 78.196721 %
#      epoch 1, minibatch 3296/3296, test error of best model 76.114527 %
# epoch 2, minibatch 3296/3296, validation error 55.683060 %
#      epoch 2, minibatch 3296/3296, test error of best model 57.536510 %
# epoch 3, minibatch 3296/3296, validation error 42.814208 %
#      epoch 3, minibatch 3296/3296, test error of best model 45.826287 %
# epoch 4, minibatch 3296/3296, validation error 36.830601 %
#      epoch 4, minibatch 3296/3296, test error of best model 40.049962 %
# epoch 5, minibatch 3296/3296, validation error 32.991803 %
#      epoch 5, minibatch 3296/3296, test error of best model 35.322829 %
# epoch 6, minibatch 3296/3296, validation error 30.204918 %
#      epoch 6, minibatch 3296/3296, test error of best model 32.071483 %
# epoch 7, minibatch 3296/3296, validation error 28.005464 %
# ...

# %%
total_number = 840
n_layer = [168, 168, 168, 168, 168]
test_mlp(activation=T.tanh, n_layer=n_layer, n_epochs=150, verbose = True)
# Out:
# ... loading data
# ... building the model
# ... training
# epoch 1, minibatch 3296/3296, validation error 74.043716 %
#      epoch 1, minibatch 3296/3296, test error of best model 73.435819 %
# epoch 2, minibatch 3296/3296, validation error 53.879781 %
#      epoch 2, minibatch 3296/3296, test error of best model 55.757110 %
# epoch 3, minibatch 3296/3296, validation error 45.013661 %
#      epoch 3, minibatch 3296/3296, test error of best model 47.598002 %
# epoch 4, minibatch 3296/3296, validation error 38.702186 %
#      epoch 4, minibatch 3296/3296, test error of best model 41.475788 %
# epoch 5, minibatch 3296/3296, validation error 35.300546 %
#      epoch 5, minibatch 3296/3296, test error of best model 37.940046 %
# epoch 6, minibatch 3296/3296, validation error 32.773224 %
#      epoch 6, minibatch 3296/3296, test error of best model 34.550346 %
# epoch 7, minibatch 3296/3296, validation error 31.079235 %
# ...

# %%
total_number = 840
n_layer = [140, 140, 140, 140, 140, 140]
test_mlp(activation=T.tanh, n_layer=n_layer, n_epochs=150, verbose = True)
# Out:
# ... loading data
# ... building the model
# ... training
# epoch 1, minibatch 3296/3296, validation error 75.177596 %
#      epoch 1, minibatch 3296/3296, test error of best model 74.550346 %
# epoch 2, minibatch 3296/3296, validation error 56.366120 %
#      epoch 2, minibatch 3296/3296, test error of best model 57.728670 %
# epoch 3, minibatch 3296/3296, validation error 43.360656 %
#      epoch 3, minibatch 3296/3296, test error of best model 45.883935 %
# epoch 4, minibatch 3296/3296, validation error 37.882514 %
#      epoch 4, minibatch 3296/3296, test error of best model 40.080707 %
# epoch 5, minibatch 3296/3296, validation error 33.538251 %
#      epoch 5, minibatch 3296/3296, test error of best model 35.960799 %
# epoch 6, minibatch 3296/3296, validation error 32.185792 %
#      epoch 6, minibatch 3296/3296, test error of best model 33.435819 %
# epoch 7, minibatch 3296/3296, validation error 30.614754 %
# ...

# %%
acc2 = [0.75222905457340505,
       0.80772482705611071,
       0.80545734050730211,
       0.79554189085318983,
       0.78504996156802465,
       0.78785549577248271]

# %% [markdown]
# Plot the result (reproducing Figure 2)

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
x = 1,2,3,4,5,6
fig, ax = plt.subplots()
ax.grid(True)
plt.plot(x, np.array(acc2)*100.0)
plt.xlabel('Number of Hidden Layers')
plt.ylabel('Test Accuracy, [%]')
plt.title('''Effect of Number of Layers
Total Number of Parameters in Hidden Layers is fixed to 840''')
plt.xlim(0, 8)
plt.ylim(75, 82)
plt.show()

# %% [markdown]
# Document the choice of parameters, and discuss what you discover.
# #### Parameters:
# learning_rate = 0.01
# L1_reg = 0.00
# L2_reg = 0.0001
# n_epochs = 150
# batch_size = 20
# n_neurons_in_each_layer = 250
# activation = T.tanh
# patience = 10000
# improvement_threshold = 0.995

# %% [markdown]
# #### Observation
# When the total number of hidden neurons is fixed, there is a trade off between the number of hidden layers and the number of hidden neurons in each layer. It is because both parameters are very important to the accuracy. If the number of hidden neurons in each layer is too small, then the parameter W will have small dimension, which will cause the training loss of complexity. If the number of hidden layers is too small, the training times in each neuron network will be too less. There is a peak when number of hidden layers equals to 2, which means if the total number of hidden neurons is fixed, there will exist a balance between number of hidden layers and number of hidden neurons if each layer.

# %% [markdown]
# ### Problem b: Bullet 5: Experiment with the number of neurons in hidden layers, but fix the number of hidden layers

# %%
n_layer = [250]
test_mlp(activation=T.tanh, n_layer=n_layer, n_epochs=150, verbose = True)
# Out:
# ... loading data
# ... building the model
# ... training
# epoch 1, minibatch 3296/3296, validation error 80.778689 %
#      epoch 1, minibatch 3296/3296, test error of best model 80.153728 %
# epoch 2, minibatch 3296/3296, validation error 71.816940 %
#      epoch 2, minibatch 3296/3296, test error of best model 71.906226 %
# epoch 3, minibatch 3296/3296, validation error 59.207650 %
#      epoch 3, minibatch 3296/3296, test error of best model 60.395849 %
# epoch 4, minibatch 3296/3296, validation error 49.918033 %
#      epoch 4, minibatch 3296/3296, test error of best model 51.936972 %
# epoch 5, minibatch 3296/3296, validation error 42.950820 %
#      epoch 5, minibatch 3296/3296, test error of best model 45.611068 %
# epoch 6, minibatch 3296/3296, validation error 38.661202 %
#      epoch 6, minibatch 3296/3296, test error of best model 41.448885 %
# epoch 7, minibatch 3296/3296, validation error 36.024590 %
# ...

# %%
n_layer = [500]
test_mlp(activation=T.tanh, n_layer=n_layer, n_epochs=150, verbose = True)
# Out:
# ... loading data
# ... building the model
# ... training
# epoch 1, minibatch 3296/3296, validation error 80.314208 %
#      epoch 1, minibatch 3296/3296, test error of best model 79.604151 %
# epoch 2, minibatch 3296/3296, validation error 69.767760 %
#      epoch 2, minibatch 3296/3296, test error of best model 69.996157 %
# epoch 3, minibatch 3296/3296, validation error 58.319672 %
#      epoch 3, minibatch 3296/3296, test error of best model 59.926979 %
# epoch 4, minibatch 3296/3296, validation error 49.672131 %
#      epoch 4, minibatch 3296/3296, test error of best model 51.856264 %
# epoch 5, minibatch 3296/3296, validation error 43.101093 %
#      epoch 5, minibatch 3296/3296, test error of best model 46.102998 %
# epoch 6, minibatch 3296/3296, validation error 39.357923 %
#      epoch 6, minibatch 3296/3296, test error of best model 42.305919 %
# epoch 7, minibatch 3296/3296, validation error 37.076503 %
# ...

# %%
n_layer = [750]
test_mlp(activation=T.tanh, n_layer=n_layer, n_epochs=150, verbose = True)
# Out:
# ... loading data
# ... building the model
# ... training
# epoch 1, minibatch 3296/3296, validation error 79.617486 %
#      epoch 1, minibatch 3296/3296, test error of best model 79.050730 %
# epoch 2, minibatch 3296/3296, validation error 69.890710 %
#      epoch 2, minibatch 3296/3296, test error of best model 69.780938 %
# epoch 3, minibatch 3296/3296, validation error 58.292350 %
#      epoch 3, minibatch 3296/3296, test error of best model 59.435050 %
# epoch 4, minibatch 3296/3296, validation error 50.109290 %
#      epoch 4, minibatch 3296/3296, test error of best model 52.140661 %
# epoch 5, minibatch 3296/3296, validation error 43.224044 %
#      epoch 5, minibatch 3296/3296, test error of best model 45.953113 %
# epoch 6, minibatch 3296/3296, validation error 39.467213 %
#      epoch 6, minibatch 3296/3296, test error of best model 42.271330 %
# epoch 7, minibatch 3296/3296, validation error 37.349727 %
# ...

# %%
n_layer = [1000]
test_mlp(activation=T.tanh, n_layer=n_layer, n_epochs=150, verbose = True)
# Out:
# ... loading data
# ... building the model
# ... training
# epoch 1, minibatch 3296/3296, validation error 79.289617 %
#      epoch 1, minibatch 3296/3296, test error of best model 78.789393 %
# epoch 2, minibatch 3296/3296, validation error 70.846995 %
#      epoch 2, minibatch 3296/3296, test error of best model 71.122214 %
# epoch 3, minibatch 3296/3296, validation error 59.262295 %
#      epoch 3, minibatch 3296/3296, test error of best model 60.568793 %
# epoch 4, minibatch 3296/3296, validation error 52.704918 %
#      epoch 4, minibatch 3296/3296, test error of best model 53.904689 %
# epoch 5, minibatch 3296/3296, validation error 45.314208 %
#      epoch 5, minibatch 3296/3296, test error of best model 47.532667 %
# epoch 6, minibatch 3296/3296, validation error 41.612022 %
#      epoch 6, minibatch 3296/3296, test error of best model 43.239816 %
# epoch 7, minibatch 3296/3296, validation error 39.180328 %
# ...

# %%
n_layer = [1250]
test_mlp(activation=T.tanh, n_layer=n_layer, n_epochs=150, verbose = True)
# Out:
# ... loading data
# ... building the model
# ... training
# epoch 1, minibatch 3296/3296, validation error 78.838798 %
#      epoch 1, minibatch 3296/3296, test error of best model 78.627978 %
# epoch 2, minibatch 3296/3296, validation error 70.191257 %
#      epoch 2, minibatch 3296/3296, test error of best model 70.461184 %
# epoch 3, minibatch 3296/3296, validation error 60.819672 %
#      epoch 3, minibatch 3296/3296, test error of best model 60.622598 %
# epoch 4, minibatch 3296/3296, validation error 52.964481 %
#      epoch 4, minibatch 3296/3296, test error of best model 53.977709 %
# epoch 5, minibatch 3296/3296, validation error 45.846995 %
#      epoch 5, minibatch 3296/3296, test error of best model 48.055342 %
# epoch 6, minibatch 3296/3296, validation error 41.243169 %
#      epoch 6, minibatch 3296/3296, test error of best model 43.716372 %
# epoch 7, minibatch 3296/3296, validation error 38.483607 %
# ...

# %%
acc3 = [0.78470407378939278,
       0.78312836279784781,
       0.79500384319754036,
       0.7551114527286702,
       0.78343581860107614]

# %% [markdown]
# Plot the result (reproducing Figure 3)

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
x = 250,500,750,1000,1250
fig, ax = plt.subplots()
ax.grid(True)
plt.plot(x, np.array(acc3)*100.0)
plt.xlabel('Number of Neurons in the Hidden Layer')
plt.ylabel('Test Accuracy, [%]')
plt.title('''Effect of Number of Neurons in Hidden Layer 
The MLP contains 1 hidden layer''')
plt.xlim(0, 1500)
plt.ylim(70, 82)
plt.show()

# %% [markdown]
# Document the choice of parameters, and discuss what you discover.
# #### Parameters:
# learning_rate = 0.01
# L1_reg = 0.00
# L2_reg = 0.0001
# n_epochs = 150
# batch_size = 20
# n_neurons_in_each_layer = 250
# activation = T.tanh
# patience = 10000
# improvement_threshold = 0.995

# %% [markdown]
# #### Observation
# There is a peak when number of neurons in the hidden layer equals to 750. It is because when the number of neurons in the hidden layer is too small, the learning ability of neuron network is weak and the test accuracy is not convergent. When the number of neurons on the hidden layer is too big, it will cause overfit and the test accuracy will be bad.

# %% [markdown]
# ### Problem c: Bullet 1: Implement MLP(with dropout) with the parameters specified

# %%
import theano
import theano.tensor as T
from hw2c import load_data, LogisticRegression, DropoutHiddenLayer, test_mlp_dropout
# Out:
# Using gpu device 0: GRID K520 (CNMeM is disabled, cuDNN Version is too old. Update to v5, was 3007.)

# %%
acc_result = test_mlp_dropout(learning_rate=0.01, L1_reg=0.0, L2_reg=0.0001, n_epochs=500,
             batch_size=20, n_hidden=[500,500], verbose=True, hidlayers=2, acttest=T.tanh)
print acc_result
# Out:
# ... loading data
# ... building the model
# ... training
# epoch 1, minibatch 3296/3296, validation error 81.161202 %
#      epoch 1, minibatch 3296/3296, test error of best model 80.418909 %
# epoch 2, minibatch 3296/3296, validation error 81.051913 %
#      epoch 2, minibatch 3296/3296, test error of best model 80.368947 %
# epoch 3, minibatch 3296/3296, validation error 80.765027 %
#      epoch 3, minibatch 3296/3296, test error of best model 79.992314 %
# epoch 4, minibatch 3296/3296, validation error 76.024590 %
#      epoch 4, minibatch 3296/3296, test error of best model 75.215219 %
# epoch 5, minibatch 3296/3296, validation error 62.855191 %
#      epoch 5, minibatch 3296/3296, test error of best model 64.215988 %
# epoch 6, minibatch 3296/3296, validation error 56.092896 %
#      epoch 6, minibatch 3296/3296, test error of best model 57.386626 %
# epoch 7, minibatch 3296/3296, validation error 50.519126 %
# ...

# %% [markdown]
# #### Observation
# The test accuracy is very high, which reaches 85.2728670254%. It is because with dropout, the parameters will be randomly choose based on the dropout fraction. It will prevent training from overfitting.

# %% [markdown]
# ### Problem c: Bullet 2: Implement MLP(without dropout) with the parameters specified

# %%
acc_result = test_mlp_dropout(learning_rate=0.01, L1_reg=0.0, L2_reg=0.0001, n_epochs=500,
             batch_size=20, n_hidden=[500,500], verbose=True, hidlayers=2, acttest=T.tanh)
print acc_result
# Out:
# ... loading data
# ... building the model
# ... training
# epoch 1, minibatch 3296/3296, validation error 81.106557 %
#      epoch 1, minibatch 3296/3296, test error of best model 80.330515 %
# epoch 2, minibatch 3296/3296, validation error 73.032787 %
#      epoch 2, minibatch 3296/3296, test error of best model 72.498078 %
# epoch 3, minibatch 3296/3296, validation error 56.953552 %
#      epoch 3, minibatch 3296/3296, test error of best model 57.978478 %
# epoch 4, minibatch 3296/3296, validation error 46.079235 %
#      epoch 4, minibatch 3296/3296, test error of best model 47.413528 %
# epoch 5, minibatch 3296/3296, validation error 40.751366 %
#      epoch 5, minibatch 3296/3296, test error of best model 42.255957 %
# epoch 6, minibatch 3296/3296, validation error 36.243169 %
#      epoch 6, minibatch 3296/3296, test error of best model 38.378171 %
# epoch 7, minibatch 3296/3296, validation error 33.251366 %
# ...

# %% [markdown]
# ### Problem c: Bullet 2: Compare the two cases

# %% [markdown]
# #### Observation
# The test accuracy is lower than the performance of with dropout. It is because without dropout, all the parameters inside the network are passed to next layer, which will cause overfit. So, it is clearly that dropout is a good way to prevent test from overfitting.
